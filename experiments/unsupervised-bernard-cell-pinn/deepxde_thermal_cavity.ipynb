# %% [markdown]
# # DeepXDE - Bernard Cavity
#
# In this notebook i'll be implementing the bernard cavity case. I'll be following the paper Hashemi+2024 and adding some twists to make it work better as i go.

# %%
import deepxde as dde
import torch
import numpy as np

import matplotlib.pyplot as plt



dde.config.set_default_float("float64")
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.
# Set the default float type to float64

# %%
rho = 1
mu = 0.001
alpha = 0.005
D = 0.1
L = D
beta = 1.0
g = 9.81

T0 = 0
T_bottom = 1

S0 = (T0 - T0)/(T_bottom - T0)
S_bottom = (T_bottom - T0)/(T_bottom - T0)


assert T_bottom > T0, "For a Benard cell the bottom temperature should be higher than the rest"

Ra = g*beta*(T_bottom-T0)*D**3*rho/(alpha*mu)
Pr = mu/(rho*alpha)
print(f"{Ra = }, {Pr = }")
# Out:
# Ra = 1962.0000000000005, Pr = 0.2

# %%
xs = np.linspace(0, D, 20)

Ts = xs/D*(S0 + (D - xs)) + S_bottom * (D - xs)/D

plt.plot(xs, Ts, "o-")
plt.xlabel("position")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
# Define geometry

## Let's go with a square for this case
geom = dde.geometry.Rectangle(xmin=(0, 0), xmax=(L, D))

# Define boundaries and boundary conditions
def boundary_top(X,on_boundary):
    on = np.logical_and(dde.utils.isclose(X[1], D),on_boundary)
    return on


def boundary_bottom(X,on_boundary):
    on = np.logical_and(dde.utils.isclose(X[1], 0),on_boundary)
    return on

def boundary_sides(X,on_boundary):
    on = ~boundary_bottom(X, on_boundary) and ~boundary_top(X, on_boundary) and on_boundary
    return on

def boundary_walls(X,on_boundary):
    return on_boundary


## Here we will have 2 dirichlet conditions on the speed components and one in the pressure 

bc_wall_u = dde.DirichletBC(geom, lambda x: 0, boundary_walls, component=0)
bc_wall_v = dde.DirichletBC(geom, lambda x: 0, boundary_walls, component=1)

bc_top_T    = dde.DirichletBC(geom, lambda x: S0      , boundary_top, component=3)
bc_bottom_T = dde.DirichletBC(geom, lambda x: S_bottom, boundary_bottom, component=3)
bc_sides_T  = dde.NeumannBC(geom,   lambda x: 0       , boundary_sides, component=3)


# # Define pde
# def pde(X,Y):
#     """Boussinesq approximated NS equations"""
    
#     du_x = dde.grad.jacobian(Y, X, i=0, j=0)
#     du_y = dde.grad.jacobian(Y, X, i=0, j=1)
#     dv_x = dde.grad.jacobian(Y, X, i=1, j=0)
#     dv_y = dde.grad.jacobian(Y, X, i=1, j=1)
#     dp_x = dde.grad.jacobian(Y, X, i=2, j=0)
#     dp_y = dde.grad.jacobian(Y, X, i=2, j=1)
    
#     du_xx = dde.grad.hessian(Y, X, component=0, i=0, j=0)
#     du_yy = dde.grad.hessian(Y, X, component=0, i=1, j=1)
#     dv_xx = dde.grad.hessian(Y, X, component=1, i=0, j=0)
#     dv_yy = dde.grad.hessian(Y, X, component=1, i=1, j=1)
    
#     dT_x = dde.grad.jacobian(Y, X, i=3, j=0)
#     dT_y = dde.grad.jacobian(Y, X, i=3, j=1)
    
#     dT_xx = dde.grad.hessian(Y, X, component=3, i=0, j=0)
#     dT_yy = dde.grad.hessian(Y, X, component=3, i=1, j=1)

#     pde_cont   = du_x + dv_y
    
#     pde_u      = Y[:,0:1]*du_x +  Y[:,1:2]*du_y + 1/rho * dp_x - (mu/rho) * (du_xx+ du_yy)
#     pde_v      = Y[:,0:1]*dv_x +  Y[:,1:2]*dv_y + 1/rho * dp_y - (mu/rho) * (dv_xx+ dv_yy) + g*(1 - beta*(Y[:, 3:] - T0))
#     pde_energy = Y[:,0:1]*dT_x +  Y[:,1:2]*dT_y - alpha * (dT_xx + dT_yy)

    
#     return [pde_u, pde_v, pde_cont, pde_energy]


def pde_nondimensional(X,Y):
    """Nondimensional Boussinesq approximated NS equations"""
    
    du_x = dde.grad.jacobian(Y, X, i=0, j=0)
    du_y = dde.grad.jacobian(Y, X, i=0, j=1)
    dv_x = dde.grad.jacobian(Y, X, i=1, j=0)
    dv_y = dde.grad.jacobian(Y, X, i=1, j=1)
    dp_x = dde.grad.jacobian(Y, X, i=2, j=0)
    dp_y = dde.grad.jacobian(Y, X, i=2, j=1)
    
    du_xx = dde.grad.hessian(Y, X, component=0, i=0, j=0)
    du_yy = dde.grad.hessian(Y, X, component=0, i=1, j=1)
    dv_xx = dde.grad.hessian(Y, X, component=1, i=0, j=0)
    dv_yy = dde.grad.hessian(Y, X, component=1, i=1, j=1)
    
    dT_x = dde.grad.jacobian(Y, X, i=3, j=0)
    dT_y = dde.grad.jacobian(Y, X, i=3, j=1)
    
    dT_xx = dde.grad.hessian(Y, X, component=3, i=0, j=0)
    dT_yy = dde.grad.hessian(Y, X, component=3, i=1, j=1)

    pde_cont   = du_x + dv_y
    pde_u      = Y[:,0:1]*du_x +  Y[:,1:2]*du_y + dp_x - (Pr/Ra)**0.5*(du_xx+ du_yy)
    pde_v      = Y[:,0:1]*dv_x +  Y[:,1:2]*dv_y + dp_y - (Pr/Ra)**0.5*(dv_xx+ dv_yy) - Y[:, 3:]
    pde_energy = Y[:,0:1]*dT_x +  Y[:,1:2]*dT_y - (dT_xx + dT_yy)/(Pr*Ra)**0.5

    
    return [pde_u, pde_v, pde_cont, pde_energy]

def non_dimensionalise_input(X):
    return X/D

def transform(X, Y):
    """Ansatz to make the spped exactly zero on the boundaries"""
    noslip_ansatz_factor = X[:, 0:1] * (L - X[:, 0:1]) * X[:, 1:2] * (D - X[:, 1:2])
    temperature_ansatz = X[:, 1:2]/D*(S0 + (D - X[:, 1:2])) + S_bottom * (D - X[:, 1:2])/D

    return torch.hstack(
        (
            noslip_ansatz_factor*Y[:, 0:2],  
            1.0 + (X[:, 0:1]**2 + X[:, 1:2]**2)**0.5*Y[:, 2:3],
            temperature_ansatz +  X[:, 1:2] * (D - X[:, 1:2])*Y[:, 3:]
        )
    )


# def dimensionalise_output(Y):
#     Y[:, 0] = Y[:, 0]

# Define model

net = dde.maps.FNN([2,] + [256]*6 + [4,], "silu", "Glorot uniform")

HARD_NOSLIP = True

if HARD_NOSLIP:
    bcs = [bc_sides_T]
    net.apply_output_transform(transform)
else:
    bcs = [bc_wall_u, bc_wall_v, bc_top_T, bc_bottom_T, bc_sides_T]

    

data = dde.data.PDE(
    geom,
    pde_nondimensional,
    bcs,
    num_domain=1024,
    num_boundary=256,
    num_test=100
)

model = dde.Model(data, net)

# %%
x, y = geom.uniform_points(100).T

plt.scatter(x, y)
plt.gca().set_aspect("equal")

# %%
class ReferencePointResampler(dde.callbacks.PDEPointResampler):
    def __init__(self, period, ref_point, **kwargs):
        super().__init__(period, bc_points=True, **kwargs)
        self.ref_point = ref_point

    
    def on_train_begin(self):
        """Add the desired reference point in the beginning of the trainining"""
        super().on_train_begin()
        bc_points = self.model.data.train_x_bc
        self.model.data.train_x_bc = np.vstack([bc_points, self.ref_point])
        

    def on_epoch_end(self):
        """
        Modification of parent method that add the reference point 
        after each resample if boundary points are being resampled.
        """

        self.epochs_since_last_resample = self.period

        act = self.epochs_since_last_resample == self.period
        
        super().on_epoch_end()
        
        # Append the reference point to BC points
        if self.bc_points and act:
            bc_points = self.model.data.train_x_bc
            self.model.data.train_x_bc = np.vstack([bc_points, self.ref_point])

# %%
data = dde.data.PDE(
    geom,
    pde_nondimensional,
    bcs,
    num_domain=1024,
    num_boundary=256,
    num_test=100
)

model = dde.Model(data, net)
model.compile("adam", lr=0.001)
# Out:
# Compiling model...
# 'compile' took 0.000252 s

# %%
resampler = ReferencePointResampler(period=100, ref_point=np.array([0, 0]))

checkpointer = dde.callbacks.ModelCheckpoint(
    filepath="model.ckpt",  # prefix and path for saved model files
    verbose=1,                           # print saving messages
    save_better_only=False,              # save every period or only if improved
    period=5_000,                       # save every epoch; set to e.g. 10 to save every 10 epochs
    monitor="train loss"                # metric to monitor, "train loss" or "test loss"
)

# %%
# Train model

#1st stage - ADAM optimizer
adam = torch.optim.Adam(net.parameters(), lr=0.001, betas=[0.9, 0.999])

model.compile(optimizer=adam)
losshistory_1, train_state_1 = model.train(iterations=97_000, callbacks=[resampler, checkpointer])

# 2nd stage - L-BFGS optimizer 
model.compile("L-BFGS")
dde.optimizers.config.set_LBFGS_options(ftol=1e-12, gtol=1e-12)
losshistory_2, train_state_2 = model.train(iterations=3_000, callbacks=[resampler, checkpointer])
# Out:
# Compiling model...
# 'compile' took 0.000075 s
#
# Training model...
#
# Step      Train loss                                            Test loss                                             Test metric
# 0         [3.06e-09, 3.65e-01, 2.31e-16, 1.02e+00, 2.57e-11]    [2.85e-09, 3.37e-01, 1.84e-16, 1.02e+00, 2.57e-11]    []
# 1000      [1.40e-03, 3.18e-03, 2.32e-05, 2.28e-04, 1.76e-05]    [7.46e-04, 7.28e-04, 1.92e-05, 1.69e-04, 1.76e-05]    []
# Epoch 1000: saving model to model.ckpt-1000.pt ...
#
# 2000      [1.50e-03, 5.05e-03, 5.36e-06, 6.34e-05, 3.20e-06]    [6.38e-04, 1.89e-03, 4.44e-06, 3.22e-05, 3.20e-06]    []
# Epoch 2000: saving model to model.ckpt-2000.pt ...
#
# 3000      [2.14e-04, 1.59e-03, 6.89e-07, 2.13e-05, 1.22e-06]    [6.45e-05, 9.77e-05, 5.69e-07, 2.18e-05, 1.22e-06]    []
# Epoch 3000: saving model to model.ckpt-3000.pt ...
#
# 4000      [3.26e-05, 1.69e-04, 8.52e-08, 6.38e-06, 5.38e-07]    [6.96e-06, 9.13e-06, 6.98e-08, 5.16e-06, 5.38e-07]    []
# Epoch 4000: saving model to model.ckpt-4000.pt ...
#
# 5000      [5.41e-05, 1.48e-04, 2.04e-08, 5.48e-06, 6.85e-07]    [1.64e-05, 3.35e-05, 1.24e-08, 3.68e-06, 6.85e-07]    []
# Epoch 5000: saving model to model.ckpt-5000.pt ...
#
# 6000      [3.06e-05, 4.55e-05, 1.40e-08, 1.75e-06, 7.17e-08]    [1.80e-05, 8.09e-06, 8.66e-09, 9.57e-07, 7.17e-08]    []
# Epoch 6000: saving model to model.ckpt-6000.pt ...
#
# 7000      [1.88e-04, 1.51e-04, 1.30e-08, 9.92e-05, 1.33e-06]    [1.20e-04, 8.87e-05, 7.76e-09, 1.44e-05, 1.33e-06]    []
# Epoch 7000: saving model to model.ckpt-7000.pt ...
#
# 8000      [2.50e-04, 1.75e-03, 1.29e-08, 1.35e-04, 9.66e-07]    [1.15e-04, 7.30e-04, 7.69e-09, 4.61e-06, 9.66e-07]    []
# Epoch 8000: saving model to model.ckpt-8000.pt ...
#
# 9000      [3.35e-05, 1.37e-04, 4.26e-08, 1.93e-06, 5.08e-08]    [6.67e-06, 8.59e-06, 2.56e-08, 2.12e-06, 5.08e-08]    []
# Epoch 9000: saving model to model.ckpt-9000.pt ...
#
# 10000     [1.26e-05, 6.30e-05, 2.37e-08, 8.58e-06, 9.10e-08]    [1.80e-06, 5.54e-06, 1.20e-08, 1.58e-06, 9.10e-08]    []
# Epoch 10000: saving model to model.ckpt-10000.pt ...
#
# 11000     [1.16e-05, 6.45e-05, 1.53e-08, 4.25e-07, 4.99e-08]    [3.78e-06, 3.24e-05, 7.24e-09, 2.50e-07, 4.99e-08]    []
# Epoch 11000: saving model to model.ckpt-11000.pt ...
#
# 12000     [1.58e-05, 3.66e-05, 1.75e-08, 1.16e-06, 9.29e-08]    [2.43e-06, 9.73e-06, 5.97e-09, 4.79e-07, 9.29e-08]    []
# Epoch 12000: saving model to model.ckpt-12000.pt ...
#
# 13000     [2.89e-05, 7.99e-05, 1.49e-08, 1.62e-06, 9.40e-08]    [1.38e-06, 3.75e-05, 5.35e-09, 2.61e-07, 9.40e-08]    []
# Epoch 13000: saving model to model.ckpt-13000.pt ...
#
# 14000     [4.81e-06, 2.07e-05, 1.35e-08, 3.23e-07, 1.74e-08]    [1.14e-06, 5.39e-06, 5.47e-09, 1.68e-07, 1.74e-08]    []
# Epoch 14000: saving model to model.ckpt-14000.pt ...
#
# 15000     [1.09e-05, 2.80e-05, 1.66e-08, 5.34e-07, 1.68e-08]    [2.03e-06, 8.58e-06, 6.85e-09, 1.72e-07, 1.68e-08]    []
# Epoch 15000: saving model to model.ckpt-15000.pt ...
#
# 16000     [9.21e-05, 6.73e-04, 1.23e-08, 3.25e-06, 1.13e-08]    [4.11e-05, 3.62e-04, 5.90e-09, 2.94e-07, 1.13e-08]    []
# Epoch 16000: saving model to model.ckpt-16000.pt ...
#
# 17000     [1.32e-06, 5.72e-06, 1.25e-08, 3.38e-07, 1.83e-08]    [2.14e-07, 6.41e-07, 5.60e-09, 1.14e-07, 1.83e-08]    []
# Epoch 17000: saving model to model.ckpt-17000.pt ...
#
# 18000     [6.86e-06, 1.96e-05, 9.57e-09, 2.41e-07, 1.94e-08]    [1.74e-06, 5.84e-06, 4.88e-09, 4.53e-08, 1.94e-08]    []
# Epoch 18000: saving model to model.ckpt-18000.pt ...
#
# 19000     [1.68e-06, 1.66e-05, 1.61e-08, 3.52e-07, 9.77e-09]    [7.19e-07, 7.50e-06, 5.78e-09, 1.70e-07, 9.77e-09]    []
# Epoch 19000: saving model to model.ckpt-19000.pt ...
#
# 20000     [3.49e-06, 1.24e-05, 1.35e-08, 3.47e-07, 5.04e-08]    [6.77e-07, 8.41e-07, 5.15e-09, 1.39e-07, 5.04e-08]    []
# Epoch 20000: saving model to model.ckpt-20000.pt ...
#
# 21000     [1.71e-06, 5.02e-06, 1.16e-08, 2.97e-07, 2.07e-08]    [2.93e-07, 4.51e-07, 4.05e-09, 1.24e-07, 2.07e-08]    []
# Epoch 21000: saving model to model.ckpt-21000.pt ...
#
# 22000     [1.86e-06, 7.94e-06, 1.06e-08, 3.51e-07, 8.85e-09]    [4.19e-07, 2.24e-06, 4.08e-09, 5.85e-08, 8.85e-09]    []
# Epoch 22000: saving model to model.ckpt-22000.pt ...
#
# 23000     [5.52e-05, 1.65e-04, 3.68e-08, 1.45e-06, 7.06e-07]    [3.48e-06, 1.23e-05, 1.31e-08, 8.97e-07, 7.06e-07]    []
# Epoch 23000: saving model to model.ckpt-23000.pt ...
#
# 24000     [1.29e-05, 4.67e-05, 2.07e-08, 4.14e-07, 5.62e-08]    [1.37e-06, 2.22e-05, 6.20e-09, 3.02e-07, 5.62e-08]    []
# Epoch 24000: saving model to model.ckpt-24000.pt ...
#
# 25000     [5.85e-06, 9.18e-06, 1.75e-08, 9.14e-07, 4.70e-08]    [5.05e-07, 2.41e-06, 5.42e-09, 2.42e-07, 4.70e-08]    []
# Epoch 25000: saving model to model.ckpt-25000.pt ...
#
# 26000     [5.92e-06, 5.60e-05, 1.50e-08, 9.40e-07, 1.98e-08]    [3.40e-06, 4.11e-05, 5.97e-09, 1.82e-07, 1.98e-08]    []
# Epoch 26000: saving model to model.ckpt-26000.pt ...
#
# 27000     [7.51e-06, 2.21e-05, 1.28e-08, 4.33e-07, 1.06e-08]    [1.54e-06, 5.57e-06, 5.40e-09, 9.69e-08, 1.06e-08]    []
# Epoch 27000: saving model to model.ckpt-27000.pt ...
#
# 28000     [4.58e-06, 1.86e-05, 1.07e-08, 1.71e-07, 6.43e-09]    [3.86e-06, 1.68e-05, 4.66e-09, 5.61e-08, 6.43e-09]    []
# Epoch 28000: saving model to model.ckpt-28000.pt ...
#
# 29000     [3.44e-06, 1.28e-05, 9.28e-09, 6.86e-08, 1.15e-08]    [1.35e-06, 3.92e-06, 3.69e-09, 4.04e-08, 1.15e-08]    []
# Epoch 29000: saving model to model.ckpt-29000.pt ...
#
# 30000     [1.11e-06, 1.39e-06, 1.22e-08, 1.05e-07, 2.00e-08]    [5.29e-07, 7.18e-07, 3.98e-09, 6.39e-08, 2.00e-08]    []
# Epoch 30000: saving model to model.ckpt-30000.pt ...
#
# 31000     [8.17e-06, 2.54e-05, 9.52e-09, 7.27e-08, 7.96e-09]    [3.94e-06, 6.08e-06, 3.37e-09, 5.51e-08, 7.96e-09]    []
# Epoch 31000: saving model to model.ckpt-31000.pt ...
#
# 32000     [2.12e-06, 6.55e-06, 9.93e-09, 1.06e-07, 1.22e-08]    [1.14e-06, 3.40e-06, 2.28e-09, 5.30e-08, 1.22e-08]    []
# Epoch 32000: saving model to model.ckpt-32000.pt ...
#
# 33000     [6.88e-06, 5.23e-05, 8.08e-09, 1.03e-06, 8.18e-09]    [3.01e-06, 1.82e-05, 2.69e-09, 6.81e-08, 8.18e-09]    []
# Epoch 33000: saving model to model.ckpt-33000.pt ...
#
# 34000     [2.16e-05, 5.94e-05, 1.36e-08, 1.04e-06, 3.46e-08]    [2.08e-05, 4.19e-05, 1.96e-09, 1.81e-07, 3.46e-08]    []
# Epoch 34000: saving model to model.ckpt-34000.pt ...
#
# 35000     [7.06e-06, 2.97e-05, 9.52e-09, 5.51e-07, 1.21e-08]    [3.44e-06, 9.39e-06, 2.62e-09, 5.00e-08, 1.21e-08]    []
# Epoch 35000: saving model to model.ckpt-35000.pt ...
#
# 36000     [8.76e-06, 1.34e-05, 1.04e-08, 1.38e-07, 9.81e-09]    [8.41e-06, 9.22e-06, 2.78e-09, 3.13e-08, 9.81e-09]    []
# Epoch 36000: saving model to model.ckpt-36000.pt ...
#
# 37000     [2.38e-06, 1.68e-05, 8.55e-09, 5.23e-08, 4.58e-09]    [1.76e-06, 1.46e-05, 3.21e-09, 2.35e-08, 4.58e-09]    []
# Epoch 37000: saving model to model.ckpt-37000.pt ...
#
# 38000     [1.13e-06, 2.58e-06, 1.29e-08, 1.93e-07, 1.74e-08]    [4.59e-07, 4.41e-07, 2.72e-09, 7.92e-08, 1.74e-08]    []
# Epoch 38000: saving model to model.ckpt-38000.pt ...
#
# 39000     [2.85e-06, 7.83e-06, 8.88e-09, 2.00e-06, 8.41e-09]    [2.26e-06, 6.41e-06, 3.02e-09, 1.52e-07, 8.41e-09]    []
# Epoch 39000: saving model to model.ckpt-39000.pt ...
#
# 40000     [8.67e-07, 1.28e-06, 6.88e-09, 3.65e-08, 5.38e-09]    [7.39e-07, 5.51e-07, 2.47e-09, 2.20e-08, 5.38e-09]    []
# Epoch 40000: saving model to model.ckpt-40000.pt ...
#
# 41000     [1.23e-07, 2.58e-07, 6.72e-09, 2.63e-08, 3.42e-09]    [4.46e-08, 5.81e-08, 2.31e-09, 1.35e-08, 3.42e-09]    []
# Epoch 41000: saving model to model.ckpt-41000.pt ...
#
# 42000     [1.50e-07, 2.02e-07, 7.33e-09, 2.24e-08, 5.79e-09]    [5.37e-08, 6.02e-08, 1.81e-09, 1.37e-08, 5.79e-09]    []
# Epoch 42000: saving model to model.ckpt-42000.pt ...
#
# 43000     [2.10e-06, 4.12e-06, 8.40e-09, 2.62e-07, 7.16e-09]    [1.61e-06, 1.28e-06, 1.32e-09, 9.25e-08, 7.16e-09]    []
# Epoch 43000: saving model to model.ckpt-43000.pt ...
#
# 44000     [4.89e-07, 3.86e-06, 5.36e-09, 2.96e-08, 4.64e-09]    [2.14e-07, 1.82e-06, 2.00e-09, 1.25e-08, 4.64e-09]    []
# Epoch 44000: saving model to model.ckpt-44000.pt ...
#
# 45000     [4.31e-06, 1.08e-05, 6.79e-09, 4.36e-07, 1.13e-08]    [3.64e-06, 5.66e-06, 1.18e-09, 6.69e-08, 1.13e-08]    []
# Epoch 45000: saving model to model.ckpt-45000.pt ...
#
# 47000     [1.90e-06, 9.80e-06, 3.44e-09, 4.19e-08, 2.93e-09]    [7.48e-07, 2.30e-06, 1.09e-09, 1.31e-08, 2.93e-09]    []
# Epoch 47000: saving model to model.ckpt-47000.pt ...
#
# 48000     [5.71e-06, 2.65e-05, 3.23e-09, 1.65e-07, 4.96e-09]    [5.02e-06, 2.58e-05, 1.08e-09, 2.70e-08, 4.96e-09]    []
# Epoch 48000: saving model to model.ckpt-48000.pt ...
#
# 49000     [3.13e-06, 1.71e-05, 5.90e-09, 2.84e-07, 1.35e-08]    [1.34e-06, 3.48e-06, 1.57e-09, 3.45e-08, 1.35e-08]    []
# Epoch 49000: saving model to model.ckpt-49000.pt ...
#
# 50000     [8.01e-07, 2.87e-06, 3.94e-09, 2.05e-07, 2.12e-09]    [3.37e-07, 1.22e-06, 1.41e-09, 2.12e-08, 2.12e-09]    []
# Epoch 50000: saving model to model.ckpt-50000.pt ...
#
# 51000     [1.29e-06, 2.95e-06, 6.92e-09, 3.58e-07, 2.93e-08]    [2.86e-07, 7.88e-07, 1.23e-09, 1.25e-07, 2.93e-08]    []
# Epoch 51000: saving model to model.ckpt-51000.pt ...
#
# 52000     [3.55e-06, 1.49e-05, 4.17e-09, 4.05e-07, 4.98e-09]    [1.05e-06, 3.35e-06, 1.30e-09, 4.14e-08, 4.98e-09]    []
# Epoch 52000: saving model to model.ckpt-52000.pt ...
#
# 53000     [2.75e-07, 9.11e-07, 2.92e-09, 3.36e-08, 1.99e-09]    [1.45e-07, 3.95e-07, 1.03e-09, 2.80e-08, 1.99e-09]    []
# Epoch 53000: saving model to model.ckpt-53000.pt ...
#
# 54000     [1.40e-07, 2.91e-07, 2.41e-09, 2.00e-08, 1.15e-09]    [1.03e-07, 2.55e-07, 8.28e-10, 2.28e-08, 1.15e-09]    []
# Epoch 54000: saving model to model.ckpt-54000.pt ...
#
# 55000     [7.62e-08, 1.84e-07, 2.52e-09, 4.72e-08, 3.52e-09]    [4.17e-08, 9.57e-08, 6.20e-10, 3.54e-08, 3.52e-09]    []
# Epoch 55000: saving model to model.ckpt-55000.pt ...
#
# 56000     [1.61e-07, 2.19e-07, 3.54e-09, 5.65e-08, 2.61e-09]    [8.55e-08, 1.26e-07, 7.18e-10, 4.30e-08, 2.61e-09]    []
# Epoch 56000: saving model to model.ckpt-56000.pt ...
#
# 57000     [9.81e-07, 1.57e-06, 2.17e-09, 2.86e-08, 1.08e-09]    [9.56e-07, 1.00e-06, 7.53e-10, 1.96e-08, 1.08e-09]    []
# Epoch 57000: saving model to model.ckpt-57000.pt ...
#
# 58000     [3.89e-07, 1.42e-06, 1.81e-09, 2.16e-08, 7.55e-10]    [3.51e-07, 1.44e-06, 7.04e-10, 1.44e-08, 7.55e-10]    []
# Epoch 58000: saving model to model.ckpt-58000.pt ...
#
# 59000     [1.39e-07, 3.71e-07, 1.63e-09, 3.38e-08, 6.55e-10]    [9.01e-08, 3.01e-07, 6.27e-10, 1.19e-08, 6.55e-10]    []
# Epoch 59000: saving model to model.ckpt-59000.pt ...
#
# 60000     [1.25e-06, 6.16e-06, 1.50e-09, 1.83e-08, 7.20e-10]    [7.37e-07, 4.03e-06, 5.28e-10, 1.08e-08, 7.20e-10]    []
# Epoch 60000: saving model to model.ckpt-60000.pt ...
#
# 61000     [9.14e-07, 2.59e-06, 3.96e-09, 1.68e-07, 5.11e-09]    [5.87e-07, 1.35e-06, 1.58e-09, 1.12e-07, 5.11e-09]    []
# Epoch 61000: saving model to model.ckpt-61000.pt ...
#
# 62000     [1.84e-06, 4.50e-06, 3.25e-09, 1.21e-07, 2.18e-09]    [1.72e-06, 2.93e-06, 1.32e-09, 3.57e-08, 2.18e-09]    []
# Epoch 62000: saving model to model.ckpt-62000.pt ...
#
# 63000     [3.46e-07, 5.32e-07, 2.67e-09, 6.77e-08, 3.80e-09]    [2.44e-07, 3.05e-07, 1.19e-09, 3.25e-08, 3.80e-09]    []
# Epoch 63000: saving model to model.ckpt-63000.pt ...
#
# 64000     [6.14e-06, 8.09e-06, 2.19e-09, 2.67e-08, 2.62e-09]    [6.26e-06, 7.18e-06, 1.03e-09, 1.96e-08, 2.62e-09]    []
# Epoch 64000: saving model to model.ckpt-64000.pt ...
#
# 65000     [3.33e-06, 5.46e-06, 7.43e-09, 4.03e-07, 2.43e-08]    [1.23e-06, 9.27e-07, 2.12e-09, 3.71e-07, 2.43e-08]    []
# Epoch 65000: saving model to model.ckpt-65000.pt ...
#
# 66000     [7.40e-07, 3.01e-06, 4.98e-09, 1.74e-07, 6.52e-09]    [3.68e-07, 1.29e-06, 2.04e-09, 1.08e-07, 6.52e-09]    []
# Epoch 66000: saving model to model.ckpt-66000.pt ...
#
# 67000     [1.25e-06, 1.64e-06, 4.35e-09, 1.33e-07, 1.26e-08]    [1.74e-07, 1.81e-07, 1.41e-09, 7.08e-08, 1.26e-08]    []
# Epoch 67000: saving model to model.ckpt-67000.pt ...
#
# 68000     [5.32e-06, 9.35e-06, 3.47e-09, 1.01e-07, 9.17e-09]    [4.10e-06, 6.44e-06, 1.42e-09, 3.69e-08, 9.17e-09]    []
# Epoch 68000: saving model to model.ckpt-68000.pt ...
#
# 69000     [3.25e-07, 7.19e-07, 3.15e-09, 7.75e-08, 7.22e-09]    [9.26e-08, 3.24e-07, 1.17e-09, 2.73e-08, 7.22e-09]    []
# Epoch 69000: saving model to model.ckpt-69000.pt ...
#
# 70000     [1.23e-06, 4.09e-06, 2.67e-09, 7.32e-08, 5.48e-09]    [6.30e-07, 2.54e-06, 1.01e-09, 3.79e-08, 5.48e-09]    []
# Epoch 70000: saving model to model.ckpt-70000.pt ...
#
# 71000     [2.98e-07, 3.16e-07, 2.67e-09, 7.87e-08, 7.92e-09]    [8.34e-08, 1.58e-07, 7.86e-10, 4.51e-08, 7.92e-09]    []
# Epoch 71000: saving model to model.ckpt-71000.pt ...
#
# 72000     [3.57e-07, 8.33e-07, 2.31e-09, 3.51e-08, 3.02e-09]    [2.11e-07, 4.20e-07, 9.17e-10, 2.06e-08, 3.02e-09]    []
# Epoch 72000: saving model to model.ckpt-72000.pt ...
#
# 73000     [7.30e-06, 1.04e-05, 2.22e-09, 5.18e-08, 2.43e-09]    [6.95e-06, 8.55e-06, 8.12e-10, 3.21e-08, 2.43e-09]    []
# Epoch 73000: saving model to model.ckpt-73000.pt ...
#
# 75000     [4.91e-06, 1.43e-05, 3.12e-09, 1.40e-07, 2.12e-09]    [3.65e-06, 8.31e-06, 6.49e-10, 2.15e-08, 2.12e-09]    []
# Epoch 75000: saving model to model.ckpt-75000.pt ...
#
# 76000     [1.31e-06, 3.85e-06, 2.68e-09, 2.79e-08, 5.94e-10]    [9.72e-07, 1.97e-06, 8.28e-10, 1.62e-08, 5.94e-10]    []
# Epoch 76000: saving model to model.ckpt-76000.pt ...
#
# 77000     [6.91e-07, 3.24e-06, 2.41e-09, 5.07e-08, 7.30e-10]    [2.24e-07, 2.49e-06, 7.16e-10, 2.31e-08, 7.30e-10]    []
# Epoch 77000: saving model to model.ckpt-77000.pt ...
#
# 78000     [1.44e-07, 6.50e-07, 2.16e-09, 2.09e-08, 5.48e-10]    [5.94e-08, 3.01e-07, 6.86e-10, 1.43e-08, 5.48e-10]    []
# Epoch 78000: saving model to model.ckpt-78000.pt ...
#
# 79000     [9.59e-07, 1.79e-06, 2.00e-09, 2.36e-08, 1.13e-09]    [9.49e-07, 1.52e-06, 6.36e-10, 1.55e-08, 1.13e-09]    []
# Epoch 79000: saving model to model.ckpt-79000.pt ...
#
# 80000     [1.59e-06, 1.25e-06, 1.86e-09, 2.58e-08, 2.31e-09]    [1.54e-06, 8.02e-07, 6.36e-10, 1.35e-08, 2.31e-09]    []
# Epoch 80000: saving model to model.ckpt-80000.pt ...
#
# 81000     [1.92e-07, 1.97e-07, 1.77e-09, 2.35e-08, 1.04e-09]    [1.42e-07, 6.61e-08, 6.50e-10, 1.61e-08, 1.04e-09]    []
# Epoch 81000: saving model to model.ckpt-81000.pt ...
#
# 82000     [1.90e-07, 4.07e-07, 2.40e-09, 2.21e-08, 1.61e-09]    [5.22e-08, 8.04e-08, 6.29e-10, 1.39e-08, 1.61e-09]    []
# Epoch 82000: saving model to model.ckpt-82000.pt ...
#
# 83000     [4.39e-07, 4.32e-07, 1.97e-09, 1.32e-08, 2.79e-10]    [3.69e-07, 2.88e-07, 6.53e-10, 1.14e-08, 2.79e-10]    []
# Epoch 83000: saving model to model.ckpt-83000.pt ...
#
# 84000     [1.22e-07, 7.59e-07, 1.80e-09, 2.33e-08, 4.30e-10]    [6.46e-08, 5.49e-07, 6.17e-10, 1.64e-08, 4.30e-10]    []
# Epoch 84000: saving model to model.ckpt-84000.pt ...
#
# 85000     [6.30e-07, 1.47e-06, 2.70e-09, 1.25e-07, 3.87e-09]    [2.41e-07, 2.81e-07, 7.16e-10, 6.61e-08, 3.87e-09]    []
# Epoch 85000: saving model to model.ckpt-85000.pt ...
#
# 86000     [3.65e-07, 2.17e-06, 1.78e-09, 2.00e-08, 4.28e-10]    [9.83e-08, 3.25e-07, 7.14e-10, 1.03e-08, 4.28e-10]    []
# Epoch 86000: saving model to model.ckpt-86000.pt ...
#
# 87000     [3.74e-05, 5.12e-05, 5.04e-09, 2.72e-06, 4.61e-07]    [2.07e-06, 4.76e-06, 2.42e-09, 7.09e-07, 4.61e-07]    []
# Epoch 87000: saving model to model.ckpt-87000.pt ...
#
# 88000     [7.54e-07, 3.19e-06, 1.52e-09, 8.37e-08, 6.96e-09]    [2.07e-07, 5.10e-07, 7.35e-10, 3.04e-08, 6.96e-09]    []
# Epoch 88000: saving model to model.ckpt-88000.pt ...
#
# 89000     [1.00e-05, 6.20e-06, 1.48e-09, 1.22e-07, 2.08e-09]    [9.60e-06, 1.26e-06, 6.34e-10, 2.17e-08, 2.08e-09]    []
# Epoch 89000: saving model to model.ckpt-89000.pt ...
#
# 90000     [2.29e-07, 2.78e-07, 1.26e-09, 5.11e-08, 2.61e-09]    [7.90e-08, 1.03e-07, 5.58e-10, 4.67e-08, 2.61e-09]    []
# Epoch 90000: saving model to model.ckpt-90000.pt ...
#
# 91000     [5.70e-07, 3.80e-07, 1.18e-09, 2.70e-08, 9.07e-10]    [4.36e-07, 1.90e-07, 5.90e-10, 2.01e-08, 9.07e-10]    []
# Epoch 91000: saving model to model.ckpt-91000.pt ...
#
# 92000     [1.51e-05, 7.74e-06, 1.17e-09, 6.89e-08, 8.92e-10]    [1.55e-05, 6.17e-06, 5.58e-10, 4.98e-08, 8.92e-10]    []
# Epoch 92000: saving model to model.ckpt-92000.pt ...
#
# 93000     [3.81e-06, 2.99e-06, 1.16e-08, 7.79e-07, 3.36e-08]    [9.84e-07, 1.12e-06, 6.25e-09, 6.20e-07, 3.36e-08]    []
# Epoch 93000: saving model to model.ckpt-93000.pt ...
#
# 94000     [5.43e-07, 6.95e-07, 6.19e-09, 1.42e-07, 1.90e-08]    [2.51e-07, 3.93e-07, 3.11e-09, 1.04e-07, 1.90e-08]    []
# Epoch 94000: saving model to model.ckpt-94000.pt ...
#
# 95000     [2.36e-06, 2.30e-06, 4.86e-09, 1.38e-07, 1.06e-08]    [2.38e-06, 1.97e-06, 2.80e-09, 8.36e-08, 1.06e-08]    []
# Epoch 95000: saving model to model.ckpt-95000.pt ...
#
# 96000     [1.85e-07, 5.34e-07, 3.74e-09, 7.17e-08, 5.04e-09]    [1.13e-07, 3.83e-07, 2.10e-09, 5.78e-08, 5.04e-09]    []
# Epoch 96000: saving model to model.ckpt-96000.pt ...
#
# 97000     [1.43e-07, 3.09e-07, 3.10e-09, 4.94e-08, 2.98e-09]    [9.67e-08, 2.32e-07, 1.68e-09, 4.27e-08, 2.98e-09]    []
# Epoch 97000: saving model to model.ckpt-97000.pt ...
#
#
# Best model at step 55000:
#   train loss: 3.14e-07
#   test loss: 1.77e-07
#   test metric: []
#
# 'train' took 17942.565916 s
#
# Compiling model...
# 'compile' took 0.000127 s
#
# Training model...
#
# Step      Train loss                                            Test loss                                             Test metric
# 97000     [1.43e-07, 3.09e-07, 3.10e-09, 4.94e-08, 2.98e-09]    [9.67e-08, 2.32e-07, 1.68e-09, 4.27e-08, 2.98e-09]    []
# 97632     [9.66e-08, 1.23e-07, 3.11e-09, 4.78e-08, 2.98e-09]    [6.39e-08, 7.26e-08, 1.68e-09, 4.12e-08, 2.98e-09]    []
# 98257     [9.61e-08, 1.22e-07, 3.10e-09, 4.74e-08, 2.91e-09]    [6.35e-08, 7.20e-08, 1.68e-09, 4.09e-08, 2.91e-09]    []
# 98882     [9.55e-08, 1.22e-07, 3.10e-09, 4.71e-08, 2.85e-09]    [6.32e-08, 7.16e-08, 1.68e-09, 4.05e-08, 2.85e-09]    []
# 99507     [9.50e-08, 1.21e-07, 3.10e-09, 4.68e-08, 2.81e-09]    [6.29e-08, 7.12e-08, 1.68e-09, 4.02e-08, 2.81e-09]    []
# 100132    [9.45e-08, 1.21e-07, 3.09e-09, 4.65e-08, 2.76e-09]    [6.27e-08, 7.08e-08, 1.68e-09, 3.98e-08, 2.76e-09]    []
# 100757    [9.41e-08, 1.20e-07, 3.09e-09, 4.62e-08, 2.72e-09]    [6.24e-08, 7.04e-08, 1.68e-09, 3.95e-08, 2.72e-09]    []
# 101382    [9.36e-08, 1.19e-07, 3.09e-09, 4.60e-08, 2.69e-09]    [6.22e-08, 7.00e-08, 1.68e-09, 3.92e-08, 2.69e-09]    []
# 102007    [9.32e-08, 1.19e-07, 3.09e-09, 4.57e-08, 2.65e-09]    [6.19e-08, 6.96e-08, 1.68e-09, 3.89e-08, 2.65e-09]    []
# 102632    [9.28e-08, 1.18e-07, 3.09e-09, 4.55e-08, 2.62e-09]    [6.17e-08, 6.93e-08, 1.68e-09, 3.86e-08, 2.62e-09]    []
# 103257    [9.24e-08, 1.18e-07, 3.08e-09, 4.52e-08, 2.59e-09]    [6.14e-08, 6.89e-08, 1.68e-09, 3.83e-08, 2.59e-09]    []
# 103882    [9.21e-08, 1.17e-07, 3.08e-09, 4.50e-08, 2.57e-09]    [6.12e-08, 6.87e-08, 1.68e-09, 3.80e-08, 2.57e-09]    []
# 104507    [9.17e-08, 1.17e-07, 3.08e-09, 4.48e-08, 2.54e-09]    [6.10e-08, 6.83e-08, 1.68e-09, 3.78e-08, 2.54e-09]    []
# 105132    [9.14e-08, 1.16e-07, 3.08e-09, 4.46e-08, 2.51e-09]    [6.08e-08, 6.81e-08, 1.68e-09, 3.75e-08, 2.51e-09]    []
# 105757    [9.10e-08, 1.16e-07, 3.07e-09, 4.43e-08, 2.49e-09]    [6.06e-08, 6.77e-08, 1.68e-09, 3.73e-08, 2.49e-09]    []
# 106382    [9.07e-08, 1.15e-07, 3.07e-09, 4.41e-08, 2.47e-09]    [6.04e-08, 6.75e-08, 1.68e-09, 3.70e-08, 2.47e-09]    []
# 107007    [9.04e-08, 1.15e-07, 3.07e-09, 4.39e-08, 2.45e-09]    [6.01e-08, 6.71e-08, 1.68e-09, 3.68e-08, 2.45e-09]    []
# 107632    [9.00e-08, 1.15e-07, 3.07e-09, 4.37e-08, 2.42e-09]    [6.00e-08, 6.69e-08, 1.68e-09, 3.65e-08, 2.42e-09]    []
# 108257    [8.98e-08, 1.14e-07, 3.06e-09, 4.35e-08, 2.40e-09]    [5.98e-08, 6.66e-08, 1.68e-09, 3.63e-08, 2.40e-09]    []
# 108882    [8.94e-08, 1.14e-07, 3.06e-09, 4.33e-08, 2.38e-09]    [5.96e-08, 6.64e-08, 1.68e-09, 3.61e-08, 2.38e-09]    []
# 109507    [8.92e-08, 1.13e-07, 3.06e-09, 4.32e-08, 2.37e-09]    [5.94e-08, 6.61e-08, 1.67e-09, 3.59e-08, 2.37e-09]    []
# 110132    [8.89e-08, 1.13e-07, 3.06e-09, 4.30e-08, 2.35e-09]    [5.92e-08, 6.58e-08, 1.67e-09, 3.57e-08, 2.35e-09]    []
# 110757    [8.86e-08, 1.12e-07, 3.05e-09, 4.28e-08, 2.33e-09]    [5.90e-08, 6.55e-08, 1.67e-09, 3.55e-08, 2.33e-09]    []
# 111382    [8.83e-08, 1.12e-07, 3.05e-09, 4.26e-08, 2.31e-09]    [5.89e-08, 6.53e-08, 1.67e-09, 3.53e-08, 2.31e-09]    []
# 112007    [8.81e-08, 1.12e-07, 3.05e-09, 4.25e-08, 2.30e-09]    [5.87e-08, 6.51e-08, 1.67e-09, 3.51e-08, 2.30e-09]    []
#
# Best model at step 112007:
#   train loss: 2.47e-07
#   test loss: 1.63e-07
#   test metric: []
#
# 'train' took 4955.319979 s

# %%
# model.restore("path/to/model.ckpt-xxx", verbose=1)

# %%
samples = geom.uniform_points(1000)
res = model.predict(samples) 

x, y = samples.T
u, v, p, T = res.T

plt.scatter(x, y, c=p)
plt.colorbar()

plt.gca().set_aspect("equal")
# Out:
# Warning: 1000 points required, but 1024 points sampled.

# %%
V = np.sqrt(v**2 + u**2)
plt.scatter(x, y, c=v, alpha=0.5, cmap="inferno")

plt.gca().set_aspect("equal")

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.quiver(x, y, u, v)
# plt.gca().set_aspect("equal")

# %%
samples = geom.random_boundary_points(1000)
res = model.predict(samples)

x, y = samples.T
u, v, p, T = res.T

V = np.sqrt(v**2 + u**2)
plt.scatter(x, y, c=v, alpha=0.8)

plt.colorbar()
plt.gca().set_aspect("equal")

# %%
samples = geom.random_boundary_points(1000)
res = model.predict(samples)

x, y = samples.T
u, v, p, T = res.T

plt.scatter(x, y, c=p, alpha=0.8)

plt.colorbar()

plt.gca().set_aspect("equal")

# %%
du_x = dde.grad.jacobian(Y, X, i=0, j=0)
du_y = dde.grad.jacobian(Y, X, i=0, j=1)
